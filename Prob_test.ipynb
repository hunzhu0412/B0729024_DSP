# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "IMG_6078.JPG" 
Image(filename = PATH , width=1896, height=2592)

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# ##### [1]

# %%
#(b)
st.norm.cdf(1,0,1)-st.norm.cdf(-1,0,1)
# Out:
# 0.6826894921370859

# %%
0.05/2
# Out:
# 0.025

# %%
#(c)
x= st.norm.ppf(0.025)
x
# Out:
# -1.9599639845400545

# %%
(g)
st.chi2.pdf()

# %% [markdown]
# ##### [2]

# %%
#(h)
#1-F(3;3)
st.gamma.sf(x=3,a=3,scale=1)
# Out:
# 0.42319008112684364

# %%
#(i)
st.gamma.sf(x=7,a=3,scale=1)
# Out:
# 0.029636163880521763

# %% [markdown]
# because 0.03<0.05
# ⇒reject α=3,β=1
