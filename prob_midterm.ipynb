# %% [markdown]
# ### [1]

# %%
from IPython.display import Image
from IPython.core.display import HTML 
PATH = "prob.JPG" 
Image(filename = PATH , width=1896, height=2592)

# %% [markdown]
# ### [2]

# %% [markdown]
# ##### (5.)
# ##### 不能接受，因為原本假設100天內平均100件，而 w > 120 的情況經常發生，代表可接受的機率為約為 39% ，因此此假設不可接受。

# %% [markdown]
# ### [3]

# %% [markdown]
# ##### (1.)

# %%
import scipy.stats as st
p= .05
n= 100
prob= st.binom.sf(k= 9,n= n,p= p) #P("w>9")
prob
# Out:
# 0.028188294163416006

# %% [markdown]
# ##### (2.)

# %% [markdown]
# ##### 我覺得可以接受，因為只有約3%會發生超過10個缺陷。
